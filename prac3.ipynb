# %%
import pandas as pd
import numpy as np

# %%
data={
    'Age':np.random.randint(20, 60, size=100),
    'Income':np.random.randint(40000, 100000, size=100),
    'Gender':np.random.choice(['Male', 'Female'], size=100)
}

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#    Age  Income  Gender
# 0   37   46982    Male
# 1   55   89228    Male
# 2   22   90676  Female
# 3   54   41420  Female
# 4   56   64127    Male

# %%
df.shape
# Out:
# (100, 3)

# %%
df.describe()
# Out:
#               Age        Income
# count  100.000000    100.000000
# mean    39.740000  69971.910000
# std     11.618185  18087.317866
# min     20.000000  41420.000000
# 25%     30.750000  53267.750000
# 50%     38.500000  67916.000000
# 75%     51.250000  88639.750000
# max     58.000000  99949.000000

# %%
df.groupby('Age').describe()
# Out:
#     Income                                                                    \
#      count          mean           std      min       25%      50%       75%
# Age
# 20     1.0  61785.000000           NaN  61785.0  61785.00  61785.0  61785.00
# 22     2.0  78193.500000  17652.920792  65711.0  71952.25  78193.5  84434.75
# 23     4.0  77346.750000  15886.118728  58135.0  67382.50  80263.0  90227.25
# 24     2.0  61629.500000  12123.345763  53057.0  57343.25  61629.5  65915.75
# 25     4.0  61148.000000  17224.021559  43787.0  53204.00  57964.0  65908.00
# 26     6.0  66173.000000   6821.141078  56739.0  61864.50  67916.0  68591.50
# 28     3.0  77832.666667  15323.213512  66396.0  69127.50  71859.0  83551.00
# 29     2.0  57066.000000   5272.188161  53338.0  55202.00  57066.0  58930.00
# 30     1.0  50727.000000           NaN  50727.0  50727.00  50727.0  50727.00
# 31     3.0  76970.333333  22577.696657  50948.0  69779.00  88610.0  89981.50
# ...

# %%
df.isnull().sum()
# Out:
# Age       0
# Income    0
# Gender    0
# dtype: int64

# %%
df.groupby('Age')['Income'].describe()
# Out:
#      count          mean           std      min       25%      50%       75%  \
# Age
# 20     1.0  61785.000000           NaN  61785.0  61785.00  61785.0  61785.00
# 22     2.0  78193.500000  17652.920792  65711.0  71952.25  78193.5  84434.75
# 23     4.0  77346.750000  15886.118728  58135.0  67382.50  80263.0  90227.25
# 24     2.0  61629.500000  12123.345763  53057.0  57343.25  61629.5  65915.75
# 25     4.0  61148.000000  17224.021559  43787.0  53204.00  57964.0  65908.00
# 26     6.0  66173.000000   6821.141078  56739.0  61864.50  67916.0  68591.50
# 28     3.0  77832.666667  15323.213512  66396.0  69127.50  71859.0  83551.00
# 29     2.0  57066.000000   5272.188161  53338.0  55202.00  57066.0  58930.00
# 30     1.0  50727.000000           NaN  50727.0  50727.00  50727.0  50727.00
# 31     3.0  76970.333333  22577.696657  50948.0  69779.00  88610.0  89981.50
# 32    10.0  68530.800000  22861.557460  44298.0  47152.25  61986.0  93602.00
# ...

# %%
df.groupby('Gender').describe()
# Out:
#          Age                                                       Income  \
#        count       mean        std   min    25%   50%    75%   max  count
# Gender
# Female  58.0  39.637931  11.453488  20.0  31.25  39.0  51.75  58.0   58.0
# Male    42.0  39.880952  11.980070  23.0  29.25  38.5  51.00  58.0   42.0
#
#                                                                          \
#                 mean           std      min       25%      50%      75%
# Gender
# Female  71041.482759  18444.802197  41420.0  56442.00  70038.0  88255.5
# Male    68494.880952  17695.228231  43787.0  52307.75  65261.5  87696.5
#
#
#             max
# Gender
# Female  99949.0
# Male    95243.0

# %%
df.groupby('Gender')['Income'].describe()
# Out:
#         count          mean           std      min       25%      50%  \
# Gender
# Female   58.0  71041.482759  18444.802197  41420.0  56442.00  70038.0
# Male     42.0  68494.880952  17695.228231  43787.0  52307.75  65261.5
#
#             75%      max
# Gender
# Female  88255.5  99949.0
# Male    87696.5  95243.0

# %%
df.groupby('Income')['Age'].describe()
# Out:
#         count  mean  std   min   25%   50%   75%   max
# Income
# 41420     1.0  54.0  NaN  54.0  54.0  54.0  54.0  54.0
# 42186     1.0  42.0  NaN  42.0  42.0  42.0  42.0  42.0
# 43787     1.0  25.0  NaN  25.0  25.0  25.0  25.0  25.0
# 44004     1.0  52.0  NaN  52.0  52.0  52.0  52.0  52.0
# 44298     1.0  32.0  NaN  32.0  32.0  32.0  32.0  32.0
# ...       ...   ...  ...   ...   ...   ...   ...   ...
# 99200     1.0  54.0  NaN  54.0  54.0  54.0  54.0  54.0
# 99294     1.0  45.0  NaN  45.0  45.0  45.0  45.0  45.0
# 99296     1.0  42.0  NaN  42.0  42.0  42.0  42.0  42.0
# 99812     1.0  53.0  NaN  53.0  53.0  53.0  53.0  53.0
# 99949     1.0  51.0  NaN  51.0  51.0  51.0  51.0  51.0
#
# [100 rows x 8 columns]

# %%
df.groupby('Income')['Gender'].describe()
# Out:
#        count unique     top freq
# Income
# 41420      1      1  Female    1
# 42186      1      1  Female    1
# 43787      1      1    Male    1
# 44004      1      1  Female    1
# 44298      1      1  Female    1
# ...      ...    ...     ...  ...
# 99200      1      1  Female    1
# 99294      1      1  Female    1
# 99296      1      1  Female    1
# 99812      1      1  Female    1
# 99949      1      1  Female    1
#
# [100 rows x 4 columns]

# %%
df1=pd.read_csv('iris.csv')

# %%
df1
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df1.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
num_values=['sepal.length', 'sepal.width', 'petal.length', 'petal.width']

# %%
df1[df1['variety']=='Setosa'].describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000

# %%
df1[df1['variety']=='Versicolor'].describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
df1[df1['variety']=='Virginica'].describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
df1[num_values].apply(pd.to_numeric, errors='coerce')
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]
