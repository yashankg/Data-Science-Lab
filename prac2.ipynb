# %%
import pandas as pd
# Out:
# /tmp/ipykernel_10079/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv('academicperformance.csv')
df1=pd.read_csv('academicperformance.csv')
df2=pd.read_csv('StudentsPerformance.csv')

# %%
df
# Out:
#     Roll No Name Department Class        Result Placement  Total Marks
# 0         1   AA      AI&DS    TE   First_Class        No          638
# 1         2   AB   Computer    TE   First_Class        No          627
# 2         3   AC         IT    BE   First_Class       Yes          541
# 3         4   AD   Computer    BE  Second_Class        No          636
# 4         5   AE   Computer    BE  Second_Class       Yes          520
# ..      ...  ...        ...   ...           ...       ...          ...
# 95       96   DR         IT    BE  Second_Class       Yes          598
# 96       97   DS   Computer    BE  Second_Class        No          679
# 97       98   DT      AI&DS    TE  Second_Class       Yes          631
# 98       99   DU      AI&DS    TE   First_Class       Yes          560
# 99      100   DV         IT    TE   First_Class       Yes          588
#
# [100 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Roll No        0
# Name           0
# Department     0
# Class          0
# Result         0
# Placement      0
# Total Marks    0
# dtype: int64

# %%
df.describe()
# Out:
#           Roll No  Total Marks
# count  100.000000   100.000000
# mean    50.500000   600.120000
# std     29.011492    55.170677
# min      1.000000   503.000000
# 25%     25.750000   558.250000
# 50%     50.500000   595.500000
# 75%     75.250000   641.000000
# max    100.000000   700.000000

# %%
df.shape
# Out:
# (100, 7)

# %%
df.dtypes
# Out:
# Roll No         int64
# Name           object
# Department     object
# Class          object
# Result         object
# Placement      object
# Total Marks     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Roll No      100 non-null    int64
#  1   Name         100 non-null    object
#  2   Department   100 non-null    object
#  3   Class        100 non-null    object
#  4   Result       100 non-null    object
#  5   Placement    100 non-null    object
#  6   Total Marks  100 non-null    int64
# dtypes: int64(2), object(5)
# memory usage: 5.6+ KB

# %%
df.isna()
# Out:
#     Roll No   Name  Department  Class  Result  Placement  Total Marks
# 0     False  False       False  False   False      False        False
# 1     False  False       False  False   False      False        False
# 2     False  False       False  False   False      False        False
# 3     False  False       False  False   False      False        False
# 4     False  False       False  False   False      False        False
# ..      ...    ...         ...    ...     ...        ...          ...
# 95    False  False       False  False   False      False        False
# 96    False  False       False  False   False      False        False
# 97    False  False       False  False   False      False        False
# 98    False  False       False  False   False      False        False
# 99    False  False       False  False   False      False        False
#
# [100 rows x 7 columns]

# %%
df
# Out:
#     Roll No Name Department Class        Result Placement  Total Marks
# 0         1   AA      AI&DS    TE   First_Class        No          638
# 1         2   AB   Computer    TE   First_Class        No          627
# 2         3   AC         IT    BE   First_Class       Yes          541
# 3         4   AD   Computer    BE  Second_Class        No          636
# 4         5   AE   Computer    BE  Second_Class       Yes          520
# ..      ...  ...        ...   ...           ...       ...          ...
# 95       96   DR         IT    BE  Second_Class       Yes          598
# 96       97   DS   Computer    BE  Second_Class        No          679
# 97       98   DT      AI&DS    TE  Second_Class       Yes          631
# 98       99   DU      AI&DS    TE   First_Class       Yes          560
# 99      100   DV         IT    TE   First_Class       Yes          588
#
# [100 rows x 7 columns]

# %%
df['Total Marks'].mean()
# Out:
# 600.12

# %%
df['Total Marks'].median()
# Out:
# 595.5

# %%
df['Total Marks'].mode()
# Out:
# 0    534
# 1    618
# Name: Total Marks, dtype: int64

# %%
df.dtypes
# Out:
# Roll No         int64
# Name           object
# Department     object
# Class          object
# Result         object
# Placement      object
# Total Marks     int64
# dtype: object

# %%
df.head()
# Out:
#    Roll No Name Department Class        Result Placement  Total Marks
# 0        1   AA      AI&DS    TE   First_Class        No          638
# 1        2   AB   Computer    TE   First_Class        No          627
# 2        3   AC         IT    BE   First_Class       Yes          541
# 3        4   AD   Computer    BE  Second_Class        No          636
# 4        5   AE   Computer    BE  Second_Class       Yes          520

# %%
df['Department'] = df['Department'].astype('category')

# %%
df.dtypes
# Out:
# Roll No           int64
# Name             object
# Department     category
# Class            object
# Result           object
# Placement        object
# Total Marks       int64
# dtype: object

# %%
df['Department'].replace({'Computer':0, 'AI&DS':1, 'IT':2}, inplace=True)
# Out:
# /tmp/ipykernel_10079/2468208372.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Department'].replace({'Computer':0, 'AI&DS':1, 'IT':2}, inplace=True)
# /tmp/ipykernel_10079/2468208372.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df
# Out:
#     Roll No Name Department Class        Result Placement  Total Marks
# 0         1   AA          1    TE   First_Class        No          638
# 1         2   AB          0    TE   First_Class        No          627
# 2         3   AC          2    BE   First_Class       Yes          541
# 3         4   AD          0    BE  Second_Class        No          636
# 4         5   AE          0    BE  Second_Class       Yes          520
# ..      ...  ...        ...   ...           ...       ...          ...
# 95       96   DR          2    BE  Second_Class       Yes          598
# 96       97   DS          0    BE  Second_Class        No          679
# 97       98   DT          1    TE  Second_Class       Yes          631
# 98       99   DU          1    TE   First_Class       Yes          560
# 99      100   DV          2    TE   First_Class       Yes          588
#
# [100 rows x 7 columns]

# %%
df1
# Out:
#     Roll No Name Department Class        Result Placement  Total Marks
# 0         1   AA      AI&DS    TE   First_Class        No          638
# 1         2   AB   Computer    TE   First_Class        No          627
# 2         3   AC         IT    BE   First_Class       Yes          541
# 3         4   AD   Computer    BE  Second_Class        No          636
# 4         5   AE   Computer    BE  Second_Class       Yes          520
# ..      ...  ...        ...   ...           ...       ...          ...
# 95       96   DR         IT    BE  Second_Class       Yes          598
# 96       97   DS   Computer    BE  Second_Class        No          679
# 97       98   DT      AI&DS    TE  Second_Class       Yes          631
# 98       99   DU      AI&DS    TE   First_Class       Yes          560
# 99      100   DV         IT    TE   First_Class       Yes          588
#
# [100 rows x 7 columns]

# %%
df1.head()
# Out:
#    Roll No Name Department Class        Result Placement  Total Marks
# 0        1   AA      AI&DS    TE   First_Class        No          638
# 1        2   AB   Computer    TE   First_Class        No          627
# 2        3   AC         IT    BE   First_Class       Yes          541
# 3        4   AD   Computer    BE  Second_Class        No          636
# 4        5   AE   Computer    BE  Second_Class       Yes          520

# %%
df1.drop('Class', axis=1, inplace=True)

# %%
df1.drop(3, axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df1.drop(3, axis=0, inplace=True)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# ...

# %%
df1
# Out:
#     Roll No Name Department        Result Placement  Total Marks
# 0         1   AA      AI&DS   First_Class        No          638
# 1         2   AB   Computer   First_Class        No          627
# 2         3   AC         IT   First_Class       Yes          541
# 4         5   AE   Computer  Second_Class       Yes          520
# 5         6   AF         IT   First_Class        No          594
# ..      ...  ...        ...           ...       ...          ...
# 95       96   DR         IT  Second_Class       Yes          598
# 96       97   DS   Computer  Second_Class        No          679
# 97       98   DT      AI&DS  Second_Class       Yes          631
# 98       99   DU      AI&DS   First_Class       Yes          560
# 99      100   DV         IT   First_Class       Yes          588
#
# [99 rows x 6 columns]

# %%
df1.shape
# Out:
# (99, 6)

# %%
df.head()
# Out:
#    Roll No Name Department Class        Result Placement  Total Marks
# 0        1   AA      AI&DS    TE   First_Class        No          638
# 1        2   AB   Computer    TE   First_Class        No          627
# 2        3   AC         IT    BE   First_Class       Yes          541
# 3        4   AD   Computer    BE  Second_Class        No          636
# 4        5   AE   Computer    BE  Second_Class       Yes          520

# %%
df['Placement'].replace({'Yes':1, 'No':0}, inplace=True)
# Out:
# /tmp/ipykernel_10079/516087297.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Placement'].replace({'Yes':1, 'No':0}, inplace=True)
# /tmp/ipykernel_10079/516087297.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Placement'].replace({'Yes':1, 'No':0}, inplace=True)

# %%
df.head()
# Out:
#    Roll No Name Department Class        Result  Placement  Total Marks
# 0        1   AA      AI&DS    TE   First_Class          0          638
# 1        2   AB   Computer    TE   First_Class          0          627
# 2        3   AC         IT    BE   First_Class          1          541
# 3        4   AD   Computer    BE  Second_Class          0          636
# 4        5   AE   Computer    BE  Second_Class          1          520

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
df1.boxplot(column='Total Marks')
plt.show()

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df2.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.figure(figsize=(8,6))
df2.boxplot(column='math score')
plt.show()

# %%
df2.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
cal=['math score']
df2.boxplot(cal)
plt.show()

# %%
df2=df2[df2['math score']>28]

# %%
cal=['math score']
df2.boxplot(cal)
plt.show()
