# %%
import pandas as pd

# %%
df=pd.read_csv("students_academics.csv")

# %%
df
# Out:
#     Rollno Name Department Class        Result Placement  Total_marks
# 0        1    A   Computer    TE   Distinction        No          518
# 1        2    B      AI&DS    TE   First_Class       Yes          531
# 2        3    C      AI&DS    TE   Distinction        No          596
# 3        4    D         IT    TE  Second_Class        No          668
# 4        5    E         IT    TE   First_Class        No          583
# ..     ...  ...        ...   ...           ...       ...          ...
# 95      96   RD   Computer    BE   Distinction        No          505
# 96      97   SD         IT    BE  Second_Class        No          670
# 97      98   TD      AI&DS    TE   Distinction        No          577
# 98      99   UD   Computer    TE   First_Class       Yes          660
# 99     100   VD         IT    BE   Distinction       Yes          501
#
# [100 rows x 7 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %%
df.isna()
# Out:
#     Rollno   Name  Department  Class  Result  Placement  Total_marks
# 0    False  False       False  False   False      False        False
# 1    False  False       False  False   False      False        False
# 2    False  False       False  False   False      False        False
# 3    False  False       False  False   False      False        False
# 4    False  False       False  False   False      False        False
# ..     ...    ...         ...    ...     ...        ...          ...
# 95   False  False       False  False   False      False        False
# 96   False  False       False  False   False      False        False
# 97   False  False       False  False   False      False        False
# 98   False  False       False  False   False      False        False
# 99   False  False       False  False   False      False        False
#
# [100 rows x 7 columns]
# No charts were generated by quickchart

# %%
df.notnull()
# Out:
#     Rollno  Name  Department  Class  Result  Placement  Total_marks
# 0     True  True        True   True    True       True         True
# 1     True  True        True   True    True       True         True
# 2     True  True        True   True    True       True         True
# 3     True  True        True   True    True       True         True
# 4     True  True        True   True    True       True         True
# ..     ...   ...         ...    ...     ...        ...          ...
# 95    True  True        True   True    True       True         True
# 96    True  True        True   True    True       True         True
# 97    True  True        True   True    True       True         True
# 98    True  True        True   True    True       True         True
# 99    True  True        True   True    True       True         True
#
# [100 rows x 7 columns]

# %%
df.isnull()
# Out:
#     Rollno   Name  Department  Class  Result  Placement  Total_marks
# 0    False  False       False  False   False      False        False
# 1    False  False       False  False   False      False        False
# 2    False  False       False  False   False      False        False
# 3    False  False       False  False   False      False        False
# 4    False  False       False  False   False      False        False
# ..     ...    ...         ...    ...     ...        ...          ...
# 95   False  False       False  False   False      False        False
# 96   False  False       False  False   False      False        False
# 97   False  False       False  False   False      False        False
# 98   False  False       False  False   False      False        False
# 99   False  False       False  False   False      False        False
#
# [100 rows x 7 columns]

# %%
from sklearn import preprocessing as pps

# %%
df.isna().sum()
# Out:
# Rollno         0
# Name           0
# Department     0
# Class          0
# Result         0
# Placement      0
# Total_marks    0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Rollno         100
# Name           100
# Department     100
# Class          100
# Result         100
# Placement      100
# Total_marks    100
# dtype: int64

# %%
from sklearn import preprocessing as pps

# %%
x_norm=pps.MinMaxScaler()
df["Total_marks"]=x_norm.fit_transform(df[["Total_marks"]])

# %%
df
# Out:
#     Rollno Name Department Class        Result Placement  Total_marks
# 0        1    A   Computer    TE   Distinction        No     0.085427
# 1        2    B      AI&DS    TE   First_Class       Yes     0.150754
# 2        3    C      AI&DS    TE   Distinction        No     0.477387
# 3        4    D         IT    TE  Second_Class        No     0.839196
# 4        5    E         IT    TE   First_Class        No     0.412060
# ..     ...  ...        ...   ...           ...       ...          ...
# 95      96   RD   Computer    BE   Distinction        No     0.020101
# 96      97   SD         IT    BE  Second_Class        No     0.849246
# 97      98   TD      AI&DS    TE   Distinction        No     0.381910
# 98      99   UD   Computer    TE   First_Class       Yes     0.798995
# 99     100   VD         IT    BE   Distinction       Yes     0.000000
#
# [100 rows x 7 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %%
df.head(10)
# Out:
#    Rollno Name Department Class        Result Placement  Total_marks
# 0       1    A   Computer    TE   Distinction        No     0.085427
# 1       2    B      AI&DS    TE   First_Class       Yes     0.150754
# 2       3    C      AI&DS    TE   Distinction        No     0.477387
# 3       4    D         IT    TE  Second_Class        No     0.839196
# 4       5    E         IT    TE   First_Class        No     0.412060
# 5       6    F   Computer    BE  Second_Class        No     0.381910
# 6       7    G      AI&DS    TE   First_Class        No     0.427136
# 7       8    H   Computer    BE   First_Class        No     0.597990
# 8       9    I         IT    BE   Distinction       Yes     0.904523
# 9      10    J         IT    BE  Second_Class       Yes     0.778894

# %%
df.sort_values(by='Total_marks', ascending=True, inplace=True)

# %%
df
# Out:
#     Rollno Name Department Class        Result Placement  Total_marks
# 99     100   VD         IT    BE   Distinction       Yes     0.000000
# 77      78   ZC         IT    BE   First_Class        No     0.010050
# 21      22    V         IT    BE   Distinction        No     0.015075
# 95      96   RD   Computer    BE   Distinction        No     0.020101
# 92      93   OD      AI&DS    BE   First_Class        No     0.035176
# ..     ...  ...        ...   ...           ...       ...          ...
# 41      42   PB      AI&DS    TE   First_Class        No     0.949749
# 68      69   QC      AI&DS    TE   First_Class       Yes     0.959799
# 59      60   HC   Computer    BE   Distinction       Yes     0.964824
# 38      39   MB   Computer    BE   First_Class        No     0.969849
# 35      36   JB   Computer    BE  Second_Class        No     1.000000
#
# [100 rows x 7 columns]

# %%
df.sort_values(by='Rollno', ascending=True, inplace=True)

# %%
encoder=pps.LabelEncoder()
df["Department"]=encoder.fit_transform(df[["Department"]])
df
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#     Rollno Name  Department Class        Result Placement  Total_marks
# 0        1    A           1    TE   Distinction        No     0.085427
# 1        2    B           0    TE   First_Class       Yes     0.150754
# 2        3    C           0    TE   Distinction        No     0.477387
# 3        4    D           2    TE  Second_Class        No     0.839196
# 4        5    E           2    TE   First_Class        No     0.412060
# ..     ...  ...         ...   ...           ...       ...          ...
# 95      96   RD           1    BE   Distinction        No     0.020101
# 96      97   SD           2    BE  Second_Class        No     0.849246
# 97      98   TD           0    TE   Distinction        No     0.381910
# ...

# %%
df["Department"].unique()
# Out:
# array([1, 0, 2])

# %%
df["Placement"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
orgvalue=encoder.inverse_transform([1,0,2])
print(orgvalue)
# Out:
# [1 0 2]
